# %% [markdown]
# # **FIBONACCI**
#
# Lucas Peña Salas
#
# Andres Bonilla Duarte
#
# Jorge Andres Torres

# %%
import itertools as tools
import matplotlib.pyplot as plt
from time import time

# %%
def recursiveFibo(n):
  if n <=1:
    return n
  else:
    return (recursiveFibo(n-1)+recursiveFibo(n-2))

def iterativeFibo(n):
  a=0
  b=1
  for i in range(n):
    a=b
    b=a+b
  return a

# %%
#Recursive Fibonacci time
RecT = []
Recn = []
for i in range(50):
  Recn.append(i)
  start = time()
  recursiveFibo(i)
  finish = time()
  exectime = finish-start
  RecT.append(exectime)
plt.plot(Recn,RecT,label="Fibonacci Recursivo")
plt.plot(Recn,Recn,label="Ejecucion lineal")
plt.ylabel("Tiempo")
plt.show()

# %%
#Iterative Fibonacci time
IterT = []
Itern = []
for i in range(500):
  Itern.append(i)
  start = time()
  recursiveFibo(i)
  finish = time()
  exectime = finish-start
  IterT.append(exectime)
plt.title("Fibonacci Iterativo")
plt.plot(Itern,IterT,label="Fibonacci Iterativo")
plt.plot(Itern,Itern,label="Ejecucion lineal")
plt.ylabel("Tiempo")
plt.show()

# %% [markdown]
# La funcion de Fibonacci Iterativo Inició a corre aproximadamente a las 5:30 PM, siendo las 11:32 PM no ha terminado de ejecutarse

# %% [markdown]
# ![FiboIter.jpg](data:image/jpeg;base64,...)
